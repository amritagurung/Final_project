# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

pd.options.display.max_columns = 200

# %%
df = pd.read_csv(r'C:\Users\amrit\Desktop\final-project\Affordable_Housing.csv')
df.fillna(0,inplace=True)
df.head(500)
# Out:
#     State  Congressional_District Active_Loans AVG_Borrower_Gross_Income  \
# 0      AK                     0.0        2,926                 72,337.58
# 1      AL                     1.0        3,543                 52,733.67
# 2      AL                     2.0        2,922                 50,266.44
# 3      AL                     3.0        3,496                 50,301.94
# 4      AL                     4.0        4,699                 48,225.72
# 5      AL                     5.0        5,689                 51,169.88
# 6      AL                     6.0        3,089                 51,401.42
# 7      AL                     7.0        1,662                 52,095.04
# 8      AL                    14.0            1                 56,784.00
# 9      AR                     1.0        8,427                 46,224.40
# 10     AR                     2.0        5,576                 50,323.15
# 11     AR                     3.0        8,524                 47,661.36
# 12     AR                     4.0        5,905                 45,924.00
# 13     AZ                     1.0        4,320                 52,025.17
# 14     AZ                     2.0        1,593                 54,078.64
# 15     AZ                     3.0        3,901                 46,095.97
# 16     AZ                     4.0        5,137                 50,390.51
# 17     AZ                     5.0          389                 68,125.97
# 18     AZ                     6.0            4                 43,824.00
# 19     AZ                     7.0           11                 39,689.33
# 20     AZ                     8.0          331                 55,568.62
# 21     AZ                     9.0            3                 43,353.33
# 22     CA                     1.0        2,866                 54,661.76
# 23     CA                     2.0          813                 59,766.17
# 24     CA                     3.0        1,214                 56,672.71
# 25     CA                     4.0        2,159                 61,291.24
# 26     CA                     5.0          159                 55,442.27
# 27     CA                     6.0            3                 77,088.00
# 28     CA                     7.0           22                 74,606.78
# 29     CA                     8.0        2,426                 48,603.01
# ..    ...                     ...          ...                       ...
# 383    VI                    98.0           34                 59,317.56
# 384    VI                     0.0          157                 41,473.79
# 385    VT                     0.0        3,619                 59,745.58
# 386    WA                     1.0        2,698                 67,075.70
# 387    WA                     2.0        1,954                 64,320.89
# 388    WA                     3.0        2,735                 60,087.63
# 389    WA                     4.0        3,198                 54,931.26
# 390    WA                     5.0        1,042                 54,124.41
# 391    WA                     6.0        3,039                 59,012.62
# 392    WA                     7.0            9                 59,597.33
# 393    WA                     8.0        2,557                 65,262.55
# 394    WA                     9.0            6                 74,856.00
# 395    WA                    10.0        1,386                 60,703.88
# 396    WI                     0.0            1                 30,161.00
# 397    WI                     1.0        1,576                 59,591.53
# 398    WI                     2.0        2,967                 58,961.22
# 399    WI                     3.0        3,392                 51,670.56
# 400    WI                     5.0        1,678                 58,847.97
# 401    WI                     6.0        2,841                 53,420.95
# 402    WI                     7.0        6,236                 51,235.34
# 403    WI                     8.0        2,553                 50,744.01
# 404    WP                     1.0          733                 56,584.65
# 405    WP                    98.0           44                 64,541.39
# 406    WP                     0.0           49                 59,258.13
# 407    WV                     1.0        2,771                 49,668.15
# 408    WV                     2.0        7,259                 55,526.84
# 409    WV                     3.0        2,298                 47,553.46
# 410    WV                     6.0            1                 47,592.00
# 411    WV                    15.0            1                 53,250.00
# 412    WY                     0.0        7,734                 62,336.98
#
#      Very Low Income Low Income Moderate Income  AVG_Debt_Ratio  \
# 0                131        954           1,674             0.0
# 1                 43        347           3,110             0.0
# 2                 69        368           2,449             0.0
# 3                 79        441           2,942             0.0
# 4                152        683           3,789             0.0
# 5                226        987           4,328             0.0
# 6                 43        339           2,694             0.0
# 7                 23        138           1,493             0.0
# 8                  0          0               1             0.0
# 9                261      1,314           6,679             0.0
# 10               148        949           4,440             0.0
# 11               417      1,835           6,071             0.0
# 12               261      1,317           4,247             0.0
# 13               325      1,287           2,643             0.0
# 14               101        478           1,010             0.0
# 15               472      1,458           1,947             0.0
# 16               392      1,720           2,831             0.0
# 17                 3         76             309             0.0
# 18                 0          3               1             0.0
# 19                 1          4               4             0.0
# 20                 9        132             185             0.0
# 21                 0          2               1             0.0
# 22               129        698           2,031             0.0
# 23                18        117             673             0.0
# 24                48        282             877             0.0
# 25                61        475           1,611             0.0
# 26                 2         32             125             0.0
# 27                 0          1               2             0.0
# 28                 0          2              16             0.0
# 29               338        622           1,457             0.0
# ..               ...        ...             ...             ...
# 383                0          0              32             0.0
# 384                0          0             105             0.0
# 385               43        343           3,156             0.0
# 386               42        238           2,361             0.0
# 387               42        204           1,684             0.0
# 388               44        334           2,315             0.0
# 389               77        498           2,603             0.0
# 390               39        170             822             0.0
# 391               55        360           2,608             0.0
# 392                0          2               7             0.0
# 393               35        237           2,276             0.0
# 394                0          1               4             0.0
# 395               23        180           1,167             0.0
# 396                1          0               0             0.0
# 397               31        253           1,264             0.0
# 398               91        534           2,299             0.0
# 399              123        780           2,439             0.0
# 400               28        266           1,362             0.0
# 401               88        599           2,112             0.0
# 402              376      1,458           4,271             0.0
# 403              137        544           1,853             0.0
# 404               35        149             493             0.0
# 405                0          4              40             0.0
# 406                8          9              32             0.0
# 407               83        473           2,175             0.0
# 408              243      1,483           5,458             0.0
# 409               42        344           1,892             0.0
# 410                0          0               1             0.0
# 411                0          0               1             0.0
# 412              312      2,032           5,300             0.0
#
#     Indian_Alaskian  Asian Black Hawaiian  White Hispanic Married  \
# 0               187    132    19       24  2,578      118   1,456
# 1                19     17   481        9  3,023       90   1,562
# 2                 9     13   447        5  2,459       67   1,274
# 3                 4      4   534       10  2,952       48   1,526
# 4                12     23   137        4  4,525      164   2,309
# 5                22     31   923       11  4,715      113   2,470
# 6                 7     10   521        3  2,554       49   1,238
# 7                 0      3   584        0  1,075       21     563
# 8                 0      0     0        0      1        0       1
# 9                17     21   829       11  7,544      118   4,017
# 10               12     24   645       12  4,906      123   2,633
# 11               69     85    93       19  8,274      671   4,272
# 12               25     29   505        5  5,335      363   2,995
# 13               84     52   155       17  4,011    1,177   1,944
# 14               15     12    30        9  1,537      658     758
# 15               34     28   114        8  3,720    2,858   2,022
# 16               48     80   106       17  4,879      934   2,360
# 17                4      6     8        3    368       64     234
# 18                0      0     1        0      3        2       1
# 19                0      2     0        0      9        7       4
# 20                2      3    17        2    308       81     146
# 21                0      0     0        0      3        0       1
# 22               34     20    11        5  2,807      350   1,397
# 23               11     10     7        2    784      106     409
# 24               11     21    17        6  1,166      448     631
# 25               23     39    15        9  2,079      182   1,039
# 26                0      2     1        1    156       29      63
# 27                0      0     0        0      3        0       1
# 28                0      1     0        1     20        2      12
# 29               22     42   106       17  2,245      507   1,059
# ..              ...    ...   ...      ...    ...      ...     ...
# 383               0      0    30        0      3        6      12
# 384               0      4   142        0      9        7      53
# 385              16     10    15        2  3,583       39   1,488
# 386              18     33    19       16  2,623      160   1,418
# 387              13     34    24       19  1,876      106     877
# 388              32     16    10       13  2,677      101   1,462
# 389              32     20    26        7  3,118    1,069   1,563
# 390               7     12     7        4  1,020       42     563
# 391              34     57    31       50  2,901       99   1,297
# 392               0      0     0        0      9        2       6
# 393              27     33    40       29  2,442      154   1,170
# 394               0      0     0        0      6        1       4
# 395              17     20    38       25  1,300       71     612
# 396               0      0     0        0      1        0       0
# 397               5      5     6        2  1,559       73     675
# 398              12     18    20        2  2,922       59   1,241
# 399               8     18    10        4  3,355       31   1,369
# 400               4      8    11        2  1,657       46     702
# 401               1      7     9        2  2,823       65   1,038
# 402              31     22     7       12  6,177       65   2,233
# 403              26      8     2        4  2,518       33     829
# 404              26    188     7      465     46        9     490
# 405               0     14     0       29      1        1      29
# 406               0     26     0       18      5        0      28
# 407               5      6    18        3  2,737       29   1,137
# 408              16     51   326       13  6,860      171   2,802
# 409               1      5    42        4  2,249       15   1,085
# 410               0      0     0        0      1        0       0
# 411               0      0     0        0      1        0       1
# 412              40     26    22       10  7,632      330   3,528
#
#      AVG_No_of_Dependent  Average Hshld Size First Time Home Buyer  \
# 0                    0.9                 2.3                 2,325
# 1                    0.7                 2.2                 3,076
# 2                    0.8                 2.2                 2,449
# 3                    0.7                 2.1                 2,946
# 4                    0.7                 2.1                 3,786
# 5                    0.6                 2.0                 4,473
# 6                    0.6                 2.1                 2,631
# 7                    0.7                 2.0                 1,481
# 8                    0.0                 1.0                     1
# 9                    0.8                 2.2                 6,692
# 10                   0.8                 2.2                 4,478
# 11                   0.7                 2.3                 6,824
# 12                   0.8                 2.3                 4,629
# 13                   1.1                 2.6                 3,630
# 14                   1.2                 2.7                 1,312
# 15                   1.3                 2.9                 3,557
# 16                   0.9                 2.5                 4,189
# 17                   1.6                 3.3                   310
# 18                   1.5                 3.0                     4
# 19                   0.6                 1.7                     8
# 20                   1.1                 2.7                   277
# 21                   0.0                 1.3                     2
# 22                   1.0                 2.6                 2,563
# 23                   1.0                 2.6                   726
# 24                   1.1                 2.8                 1,116
# 25                   1.0                 2.5                 1,906
# 26                   1.0                 2.5                   146
# 27                   1.7                 3.0                     3
# 28                   1.3                 2.5                    18
# 29                   1.0                 2.5                 2,225
# ..                   ...                 ...                   ...
# 383                  0.9                 2.1                    31
# 384                  0.4                 0.7                   101
# 385                  0.5                 1.7                 3,129
# 386                  0.9                 2.5                 2,261
# 387                  0.8                 2.4                 1,654
# 388                  1.0                 2.7                 2,288
# 389                  1.1                 2.8                 2,782
# 390                  1.2                 2.8                   840
# 391                  0.8                 2.3                 2,597
# 392                  1.3                 3.0                     5
# 393                  1.0                 2.6                 2,221
# 394                  0.8                 2.7                     4
# 395                  0.9                 2.4                 1,188
# 396                  0.0                 2.0                     0
# 397                  0.7                 2.2                 1,256
# 398                  0.6                 2.1                 2,295
# 399                  0.7                 2.2                 2,588
# 400                  0.7                 2.1                 1,242
# 401                  0.6                 2.0                 2,226
# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'Asian']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
import matplotlib
cmap = matplotlib.colors.Colormap('jet', N=test.State.nunique())

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].Asian, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and Asian")
plt.xlabel("Asian")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.model_selection import train_test_split

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'Asian']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7312736048841946

# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'Hispanic']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["Hispanic"] = test['Hispanic'].str.replace(",","")
test["Hispanic"] = test.loc[:, "Hispanic"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].Hispanic, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and Hispanic")
plt.xlabel("Hispanic")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'Hispanic']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7132074067774896

# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'White']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["White"] = test['White'].str.replace(",","")
test["White"] = test.loc[:, "White"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].White, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and White")
plt.xlabel("White")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'White']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7246953856483851

# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'Indian_Alaskian']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["Indian_Alaskian"] = test['Indian_Alaskian'].str.replace(",","")
test["Indian_Alaskian"] = test.loc[:, "Indian_Alaskian"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].Indian_Alaskian, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and Indian_Alaskian")
plt.xlabel("Indian_Alaskian")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'Indian_Alaskian']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7176859512276891

# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'Black']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["Black"] = test['Black'].str.replace(",","")
test["Black"] = test.loc[:, "Black"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].Black, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and Black")
plt.xlabel("Black")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'Black']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7172300551243469

# %%
test = df[['AVG_Borrower_Gross_Income','AVG_Request_Amount', 'State', 'Hawaiian']]

test["AVG_Borrower_Gross_Income"] = test['AVG_Borrower_Gross_Income'].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test['AVG_Request_Amount'].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["Hawaiian"] = test['Hawaiian'].str.replace(",","")
test["Hawaiian"] = test.loc[:, "Hawaiian"].astype(float)
# Out:
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\amrit\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].Hawaiian, test[test.State == i].AVG_Request_Amount, cmap=cmap);
    plt.title("correlation between AVG_Borrower_Gross_Income and Hawaiian")
plt.xlabel("Hawaiian")
plt.ylabel("AVG_Borrower_Gross_Income")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'Hawaiian']].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7214979106440202
